# %%
import subprocess

options = ['Domain', 'Username', 'Phone Number', 'Email', 'Twitter']

while True:
    choice = input("Please choose one of the following options (1-5):\n" + '\n'.join(f"{i}. {opt}" for i, opt in enumerate(options, 1)))
    if choice.isdigit() and 0 < int(choice) <= len(options):
        choice = int(choice) - 1
        if choice == 0:
            domain = input("Please input your domain name: ")
            print(f"Your domain name is: {domain}")
            try:
                host_result = subprocess.run(["host", domain], capture_output=True, text=True)
                ip_address = host_result.stdout.strip().split()[-1]
                whois_result = subprocess.run(["whois", ip_address], capture_output=True, text=True)
                print(f"Result of 'host {domain}': {host_result.stdout}")
                print(f"Result of 'whois {ip_address}': {whois_result.stdout}")
            except Exception as e:
                print(f"An error occurred while running the commands: {e}")
        elif choice == 1:
            username = input("Please input your username: ")
            print(f"Your username is: {username}")
        elif choice == 2:
            phone = input("Please input your phone number: ")
            print(f"Your phone number is: {phone}")
        elif choice == 3:
            email = input("Please input your email: ")
            print(f"Your email is: {email}")
        elif choice == 4:
            twitter = input("Please input your Twitter username: ")
            print(f"Your Twitter username is: {twitter}")
        break
    print("Invalid choice, please try again.")
# Out:
# Please choose one of the following options (1-5):
# 1. Domain
# 2. Username
# 3. Phone Number
# 4. Email
# 5. Twitter 1
# Please input your domain name:  facebook.com
# Your domain name is: facebook.com
# Result of 'host facebook.com': facebook.com has address 157.240.10.35
# facebook.com has IPv6 address 2a03:2880:f12a:83:face:b00c:0:25de
# facebook.com mail is handled by 10 smtpin.vvv.facebook.com.
#
# Result of 'whois smtpin.vvv.facebook.com.': % IANA WHOIS server
# % for more information on IANA, visit http://www.iana.org
# % This query returned 1 object
#
# refer:        whois.verisign-grs.com
#
# domain:       COM
#
# organisation: VeriSign Global Registry Services
# address:      12061 Bluemont Way
# address:      Reston VA 20190
# address:      United States of America (the)
#
# contact:      administrative
# name:         Registry Customer Service
# organisation: VeriSign Global Registry Services
# address:      12061 Bluemont Way
# address:      Reston VA 20190
# ...

# %%
import os
import subprocess

options = ['Domain', 'Username', 'Phone Number', 'Email', 'Twitter']

while True:
    choice = input("Please choose one of the following options (1-5):\n" + '\n'.join(f"{i}. {opt}" for i, opt in enumerate(options, 1)))
    if choice.isdigit() and 0 < int(choice) <= len(options):
        choice = int(choice) - 1
        if choice == 0:
            domain = input("Please input your domain name: ")
            print(f"Your domain name is: {domain}")
            try:
                host_result = subprocess.run(["host", domain], capture_output=True, text=True)
                ip_address = host_result.stdout.strip().split()[-1]
                whois_result = subprocess.run(["whois", ip_address], capture_output=True, text=True)
                print(f"Result of 'host {domain}': {host_result.stdout}")
                print(f"Result of 'whois {ip_address}': {whois_result.stdout}")
                os.makedirs(domain, exist_ok=True)
                with open(os.path.join(domain, 'domain.txt'), "w") as f:
                    f.write(f"Result of 'host {domain}': {host_result.stdout}\n")
                    f.write(f"Result of 'whois {ip_address}': {whois_result.stdout}\n")
                print(f"Results saved in folder '{domain}'")
            except Exception as e:
                 print(f"An error occurred while running the commands: {e}")
        elif choice == 1:
            username = input("Please input your username: ")
            print(f"Your username is: {username}")
           # try:
            #    username_result = subprocess.run(["python3 metagoofil -d ", domain], capture_output=True, text=True)
             #   print(f"Result of 'username {username}': {username_result.stdout}")
              #  os.makedirs(domain, exist_ok=True)
               # with open(os.path.join(domain, '.txt'), "w") as f:
                #    f.write(f"Result of 'host {domain}': {host_result.stdout}\n")
                 #   f.write(f"Result of 'whois {ip_address}': {whois_result.stdout}\n")
                #print(f"Results saved in folder '{domain}'")
           # except Exception as e:
            #    print(f"An error occurred while running the commands: {e}")
        elif choice == 2:
            phone = input("Please input your phone number: ")
            print(f"Your phone number is: {phone}")
        elif choice == 3:
            email = input("Please input your email: ")
            print(f"Your email is: {email}")
        elif choice == 4:
            twitter = input("Please input your Twitter username: ")
            print(f"Your Twitter username is: {twitter}")
        break
    print("Invalid choice, please try again.")
# Out:
# Please choose one of the following options (1-5):
# 1. Domain
# 2. Username
# 3. Phone Number
# 4. Email
# 5. Twitter 1
# Please input your domain name:  twitter.com
# Your domain name is: twitter.com
# Result of 'host twitter.com': twitter.com has address 104.244.42.1
# twitter.com has address 104.244.42.65
# twitter.com mail is handled by 10 aspmx.l.google.com.
# twitter.com mail is handled by 30 ASPMX3.GOOGLEMAIL.com.
# twitter.com mail is handled by 20 alt2.aspmx.l.google.com.
# twitter.com mail is handled by 20 alt1.aspmx.l.google.com.
# twitter.com mail is handled by 30 ASPMX2.GOOGLEMAIL.com.
#
# Result of 'whois ASPMX2.GOOGLEMAIL.com.': % IANA WHOIS server
# % for more information on IANA, visit http://www.iana.org
# % This query returned 1 object
#
# refer:        whois.verisign-grs.com
#
# domain:       COM
#
# organisation: VeriSign Global Registry Services
# address:      12061 Bluemont Way
# address:      Reston VA 20190
# address:      United States of America (the)
#
# ...

# %%
import os
import subprocess

options = ['Domain', 'Username', 'Phone Number', 'Email', 'Twitter']

while True:
    choice = input("Please choose one of the following options (1-5):\n" + '\n'.join(f"{i}. {opt}" for i, opt in enumerate(options, 1)))
    if choice.isdigit() and 0 < int(choice) <= len(options):
        choice = int(choice) - 1
        if choice == 0:
            domain = input("Please input your domain name: ")
            print(f"Your domain name is: {domain}")
            try:
                host_result = subprocess.run(["host", domain], capture_output=True, text=True)
                ip_address = host_result.stdout.strip().split()[-1]
                whois_result = subprocess.run(["whois", ip_address], capture_output=True, text=True)
                os.makedirs(domain, exist_ok=True)
                with open(os.path.join(domain, "result.txt"), "w") as f:
                    f.write(f"Result of 'host {domain}': {host_result.stdout}\n")
                    f.write(f"Result of 'whois {ip_address}': {whois_result.stdout}\n"
            except Exception as e:
                print(f"An error occurred while running the commands: {e}")
        elif choice == 1:
            username = input("Please input your username: ")
            print(f"Your username is: {username}")
            try:
                username_result = subprocess.run(["python3", "sherlock" username], cwd="./subbrute", stdout=subprocess.PIPE, stderr=subprocess.PIPE)
                os.makedirs(username, exist_ok=True)
                with open(os.path.join(username, "website-list.txt"), "w") as f:
                    f.write(f"Result of 'username {username}': {username_result.stdout}\n")
            except Exception as e:
                print(f"An error occurred while running the commands: {e}")                
            
                        
        elif choice == 2:
            phone = input("Please input your phone number: ")
            print(f"Your phone number is: {phone}")
        elif choice == 3:
            email = input("Please input your email: ")
            print(f"Your email is: {email}")
        elif choice == 4:
            twitter = input("Please input your Twitter username: ")
            print(f"Your Twitter username is: {twitter}")
        break
    print("Invalid choice, please try again.")
# Out:
#   Input In [5]
#     except Exception as e:
#     ^
# SyntaxError: invalid syntax

# %%
import os
import subprocess

options = ['Domain', 'Username', 'Phone Number', 'Email', 'Twitter']

while True:
    choice = input("Please choose one of the following options (1-5):\n" + '\n'.join(f"{i}. {opt}" for i, opt in enumerate(options, 1)))
    if choice.isdigit() and 0 < int(choice) <= len(options):
        break
    print("Invalid choice, please try again.")
    
if int(choice) == 1:
    domain = input("Please input your domain name: ")
    dir_name = domain
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)
    
    with open(f"{dir_name}/host.txt", "w") as host_file:
        host_result = subprocess.run(["host", domain], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        host_file.write(host_result.stdout.decode())
    
    with open(f"{dir_name}/whois.txt", "w") as whois_file:
        ip = host_result.stdout.decode().split()[-1]
        whois_result = subprocess.run(["whois", ip], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        whois_file.write(whois_result.stdout.decode())
    
    metagoofil_result = subprocess.run(["python3", "metagoofil.py", "-d", domain, "-l", "10", "-n", "10", "-t", "all"], cwd="./metagoofil", stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    with open(f"{dir_name}/metagoofil.txt", "w") as metagoofil_file:
        metagoofil_file.write(metagoofil_result.stdout.decode())
# Out:
# Please choose one of the following options (1-5):
# 1. Domain
# 2. Username
# 3. Phone Number
# 4. Email
# 5. Twitter 1
# Please input your domain name:  facebook.com

# %%
import os
import subprocess

options = ['Domain', 'Username', 'Phone Number', 'Email', 'Twitter']

while True:
    choice = input("Please choose one of the following options (1-5):\n" + '\n'.join(f"{i}. {opt}" for i, opt in enumerate(options, 1)))
    if choice.isdigit() and 0 < int(choice) <= len(options):
        break
    print("Invalid choice, please try again.")
    
if int(choice) == 1:
    domain = input("Please input your domain name: ")
    dir_name = domain
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)
    
    with open(f"{dir_name}/host.txt", "w") as host_file:
        host_result = subprocess.run(["host", domain], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        host_file.write(host_result.stdout.decode())
    
    with open(f"{dir_name}/whois.txt", "w") as whois_file:
        ip = host_result.stdout.decode().split()[-1]
        whois_result = subprocess.run(["whois", ip], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        whois_file.write(whois_result.stdout.decode())
    
elif int(choice) == 2:
    username = input("Please input your username: ")
    #print(f"Your username is: {username}")
    
    dir_name = username
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)
    with open(f"{dir_name}/website-list.txt", "w") as sherlock_file:
        username_result = subprocess.run(["python3", "/Users/mannitor/Documents/dell/Documents/script/project/jupyter/tools/sherlock/sherlock/sherlock.py", username], cwd="./sherlock/sherlock", stdout=subprocess.PIPE, stderr=subprocess.PIPE)


    
   
   # print("Finish")
# Out:
# Please choose one of the following options (1-5):
# 1. Domain
# 2. Username
# 3. Phone Number
# 4. Email
# 5. Twitter 1

# %%
import os
import subprocess

options = ['Domain', 'Username', 'Phone Number', 'Email', 'Twitter']

while True:
    choice = input("Please choose one of the following options (1-5):\n" + '\n'.join(f"{i}. {opt}" for i, opt in enumerate(options, 1)))
    if choice.isdigit() and 0 < int(choice) <= len(options):
        choice = int(choice) - 1
        if choice == 0:
            domain = input("Please input your domain name: ")
            print(f"Your domain name is: {domain}")
            try:
                host_result = subprocess.run(["host", domain], capture_output=True, text=True)
                ip_address = host_result.stdout.strip().split()[-1]
                whois_result = subprocess.run(["whois", ip_address], capture_output=True, text=True)
                subd_result = subprocess.run(["python3", "oneforall.py", "--target", domain, "run" "--csv"], cwd="./OneForAll", capture_output=True, text=True)
                os.makedirs(domain, exist_ok=True)
                with open(os.path.join(domain, "result.txt"), "w") as f:
                    f.write(f"Result of 'host {domain}': {host_result}\n")
                    f.write(f"Result of 'whois {ip_address}': {whois_result}\n")
                    f.write(f"Result of subdomain for' {domain}': {subd_result}\n")
            except Exception as e:
                print(f"An error occurred while running the commands: {e}")
        elif choice == 1:
            username = input("Please input your username: ")
            print(f"Your username is: {username}")
            try:
                username_result = subprocess.run(["python3", "sherlock.py", username], cwd="./sherlock/sherlock", capture_output=True, text=True)
                os.makedirs(username, exist_ok=True)
                with open(os.path.join(username, "website-list.txt"), "w") as f:
                    f.write(f"Result of 'username {username}': {username_result.stdout}\n")
            except Exception as e:
                print(f"An error occurred while running the commands: {e}")                                        
        elif choice == 2:
            phone = input("Please input your phone number: ")
            print(f"Your phone number is: {phone}")
        elif choice == 3:
            email = input("Please input your email: ")
            print(f"Your email is: {email}")
        elif choice == 4:
            twitter = input("Please input your Twitter username: ")
            print(f"Your Twitter username is: {twitter}")
        break
    print("Invalid choice, please try again.")
# Out:
# Please choose one of the following options (1-5):
# 1. Domain
# 2. Username
# 3. Phone Number
# 4. Email
# 5. Twitter 1
# Please input your domain name:  uitm.edu.my
# Your domain name is: uitm.edu.my

# %%
import os
import subprocess

options = ['Domain', 'Username', 'Phone Number', 'Email', 'Twitter']

while True:
    choice = input("Please choose one of the following options (1-5):\n" + '\n'.join(f"{i}. {opt}" for i, opt in enumerate(options, 1)))
    if choice.isdigit() and 0 < int(choice) <= len(options):
        choice = int(choice) - 1
        if choice == 0:
            domain = input("Please input your domain name: ")
            print(f"Your domain name is: {domain}")
            try:
                host_result = subprocess.run(["host", domain], capture_output=True, text=True)
                ip_address = host_result.stdout.strip().split()[-1]
                whois_result = subprocess.run(["whois", ip_address], capture_output=True, text=True)
                subd_result = subprocess.run(["python3", "oneforall.py", "--target", domain, "run" "--csv"], cwd="./OneForAll", capture_output=True, text=True)
                os.makedirs(domain, exist_ok=True)
                with open(os.path.join(domain, "result.txt"), "w") as f:
                    f.write(f"Result of 'host {domain}': {host_result.stdout}\n")
                    f.write(f"Result of 'whois {ip_address}': {whois_result.stdout}\n")
                    f.write(f"Result of subdomain for' {domain}': {subd_result.stdout}\n")
            except Exception as e:
                print(f"An error occurred while running the commands: {e}")
        elif choice == 1:
            username = input("Please input your username: ")
            print(f"Your username is: {username}")
            try:
                username_result = subprocess.run(["python3", "sherlock.py", username], cwd="./sherlock/sherlock", capture_output=True, text=True)
                os.makedirs(username, exist_ok=True)
                with open(os.path.join(username, "website-list.txt"), "w") as f:
                    f.write(f"Result of 'username {username}': {username_result.stdout}\n")
            except Exception as e:
                print(f"An error occurred while running the commands: {e}")                                        
        elif choice == 2:
            phone = input("Please input your phone number: ")
            print(f"Your phone number is: {phone}")
        elif choice == 3:
            email = input("Please input your email: ")
            print(f"Your email is: {email}")
        elif choice == 4:
            twitter = input("Please input your Twitter username: ")
            print(f"Your Twitter username is: {twitter}")
        break
    print("Invalid choice, please try again.")
# Out:
# Please choose one of the following options (1-5):
# 1. Domain
# 2. Username
# 3. Phone Number
# 4. Email
# 5. Twitter 1
# Please input your domain name:  uitm.edu.my
# Your domain name is: uitm.edu.my

# %%
import os
import subprocess

options = ['Domain', 'Username', 'Phone Number', 'Email', 'Twitter']

def handle_domain_input(domain):
    try:
        host_result = subprocess.run(["host", domain], capture_output=True, text=True)
        ip_address = host_result.stdout.strip().split()[-1]
        whois_result = subprocess.run(["whois", ip_address], capture_output=True, text=True)
        subd_result = subprocess.run(["python3", "oneforall.py", "--target", domain, "run", "--csv", "--path", os.path.join(domain, "subd_result.csv")], cwd="./OneForAll", capture_output=True)
        with open(os.path.join(domain, "result.txt"), "w") as f:
            f.write(f"Result of 'host {domain}': {host_result.stdout}\n")
            f.write(f"Result of 'whois {ip_address}': {whois_result.stdout}\n")
            #f.write(f"Result of subdomain for' {domain}': {subd_result.stdout}\n")
        #with open(os.path.join(domain, f"{domain}.csv"), "w") as f:
            #f.write(subd_result.stdout)
    except Exception as e:
        print(f"An error occurred while running the commands: {e}")

def handle_username_input(username):
    try:
        username_result = subprocess.run(["python3", "sherlock.py", username], cwd="./sherlock/sherlock", capture_output=True, text=True)
        os.makedirs(username, exist_ok=True)
        with open(os.path.join(username, "website-list.txt"), "w") as f:
            f.write(f"Result of 'username {username}': {username_result.stdout}\n")
    except Exception as e:
        print(f"An error occurred while running the commands: {e}")                                        

while True:
    choice = input("Please choose one of the following options (1-5):\n" + '\n'.join(f"{i}. {opt}" for i, opt in enumerate(options, 1)))
    if choice.isdigit() and 0 < int(choice) <= len(options):
        choice = int(choice) - 1
        if choice == 0:
            domain = input("Please input your domain name: ")
            print(f"Your domain name is: {domain}")
            handle_domain_input(domain)
        elif choice == 1:
            username = input("Please input your username: ")
            print(f"Your username is: {username}")
            handle_username_input(username)
        elif choice == 2:
            phone = input("Please input your phone number: ")
            print(f"Your phone number is: {phone}")
        elif choice == 3:
            email = input("Please input your email: ")
            print(f"Your email is: {email}")
        elif choice == 4:
            twitter = input("Please input your Twitter username: ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 31>()
#      28         print(f"An error occurred while running the commands: {e}")
#      30 while True:
# ---> 31     choice = input("Please choose one of the following options (1-5):\n" + '\n'.join(f"{i}. {opt}" for i, opt in enumerate(options, 1)))
#      32     if choice.isdigit() and 0 < int(choice) <= len(options):
#      33         choice = int(choice) - 1
#
# File ~/miniforge3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
# ...

# %%
import os
import subprocess

options = ['Domain', 'Username', 'Phone Number', 'Email', 'Twitter']

def handle_domain_input(domain):
    try:
        host_result = subprocess.run(["host", domain], capture_output=True, text=True)
        ip_address = host_result.stdout.strip().split()[-1]
        whois_result = subprocess.run(["whois", ip_address], capture_output=True, text=True)
        subd_result = subprocess.run(["python3", "oneforall.py", "--target", domain, "run", "--csv", "--path", os.path.join(domain, "subd_result.csv")], cwd="./OneForAll", capture_output=True)
        with open(os.path.join(domain, "result.txt"), "w") as f:
            f.write(f"Result of 'host {domain}': {host_result.stdout}\n")
            f.write(f"Result of 'whois {ip_address}': {whois_result.stdout}\n")
            #f.write(f"Result of subdomain for' {domain}': {subd_result.stdout}\n")
        #with open(os.path.join(domain, f"{domain}.csv"), "w") as f:
            #f.write(subd_result.stdout)
    except Exception as e:
        print(f"An error occurred while running the commands: {e}")

def handle_username_input(username):
    try:
        username_result = subprocess.run(["python3", "sherlock.py", username], cwd="./sherlock/sherlock", capture_output=True, text=True)
        os.makedirs(username, exist_ok=True)
        with open(os.path.join(username, "website-list.txt"), "w") as f:
            f.write(f"Result of 'username {username}': {username_result.stdout}\n")
    except Exception as e:
        print(f"An error occurred while running the commands: {e}")  
        
'''def handle_email_input(email):
    try:
        email_result = subprocess.run(["python3" "holehe.py", email], cwd="./holeh.py", capture_output=True, text=True)
        os.makedirs(email, exist_ok=True)
        with open(os.path.join(email, "email.txt"), "w") as f:
            f.write(f"Result of 'email registered to social media account {email}': {email_result.stdout}\n")
    except Exception as e:
        print(f"An error occurred while running the commands: {e}")'''
        
def handle_email_input(email):
    try:
        email_result = subprocess.run(["holehe", "--only-used", email], capture_output=True, text=True)
        os.makedirs(email, exist_ok=True)
        with open(os.path.join(email, "email.txt"), "w") as f:
            f.write(f"Result of 'email registered to social media account {email}': {email_result.stdout}\n")
    except Exception as e:
        print(f"An error occurred while running the commands: {e}")
        
def handle_email_input(twitter):
    try:
        twitter_result = subprocess.run(["snscrape", "twitter-user", twitter], capture_output=True, text=True)
        os.makedirs(twitter, exist_ok=True)
        with open(os.path.join(twitter, "tweet.txt"), "w") as f:
            f.write(f"Result of 'tweet from username {twitter}': {twitter_result.stdout}\n")
    except Exception as e:
        print(f"An error occurred while running the commands: {e}")

while True:
    choice = input("Please choose one of the following options (1-5):\n" + '\n'.join(f"{i}. {opt}" for i, opt in enumerate(options, 1)))
    if choice.isdigit() and 0 < int(choice) <= len(options):
        choice = int(choice) - 1
        if choice == 0:
            domain = input("Please input your domain name: ")
            print(f"Your domain name is: {domain}")
            handle_domain_input(domain)
        elif choice == 1:
            username = input("Please input your username: ")
            print(f"Your username is: {username}")
            handle_username_input(username)
        elif choice == 2:
            phone = input("Please input your phone number: ")
            print(f"Your phone number is: {phone}")
        elif choice == 3:
            email = input("Please input your email: ")
            print(f"Your email is: {email}")
            handle_email_input(email)
        elif choice == 4:
            twitter = input("Please input your Twitter username: ")
            handle_email_input(twitter)
# Out:
# Please choose one of the following options (1-5):
# 1. Domain
# 2. Username
# 3. Phone Number
# 4. Email
# 5. Twitter 5
# Please input your Twitter username:  localrkyt
